# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as pyp

# %% [markdown]
# # Importing the dataset

# %%
loan_train_data=pd.read_excel('C://Users//Bachelor_001//OneDrive//Desktop//PD//loan-train 2.xlsx')
loan_train_data
pd.set_option('display.max_row',None)

# %% [markdown]
# # DATACLEANING

# %% [markdown]
# mode() >when object/categorical variable

# %%
loan_train_data.info()
loan_train_data.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# ...

# %% [markdown]
# # investigating loan id

# %%
loan_train_data['Loan_ID'].info()
loan_train_data['Loan_ID'].unique()
loan_train_data['Loan_ID'].isna().sum()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Loan_ID
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    object
# dtypes: object(1)
# memory usage: 4.9+ KB
# 0

# %% [markdown]
# # investigating gender

# %%
loan_train_data['Gender'].info()
loan_train_data['Gender'].unique()
loan_train_data['Gender'].isna().sum()
loan_train_data['Gender']=loan_train_data['Gender'].astype('category')
loan_train_data['Gender'].info()
loan_train_data[loan_train_data['Gender'].isna()]
loan_train_data['Gender'].isna().sum()
loan_train_data['Gender'].info()
loan_train_data['Gender'] = loan_train_data['Gender'].fillna(loan_train_data['Gender'].mode()[0])
loan_train_data['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 601 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 601 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 601 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes

# %% [markdown]
# ## investigating Married

# %%
loan_train_data['Married'].info()
loan_train_data['Married'].isna().sum()
loan_train_data['Married'].sample(10)
loan_train_data['Married']=loan_train_data['Married'].astype('category')
loan_train_data['Married'].info()
loan_train_data['Married'].unique()
loan_train_data['Married']=loan_train_data['Married'].fillna(loan_train_data['Married'].mode()[0])

loan_train_data[loan_train_data['Married'].isna()]
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Married
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Married
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %% [markdown]
# ## investigating Dependents

# %%
loan_train_data['Dependents'].info()
loan_train_data['Dependents'].unique()
loan_train_data['Dependents']=loan_train_data['Dependents'].astype('category')
loan_train_data['Dependents'].info()
loan_train_data['Dependents']=loan_train_data['Dependents'].replace('3+',3)
loan_train_data['Dependents'].unique()
loan_train_data[loan_train_data['Dependents'].isna()]
loan_train_data['Dependents']=loan_train_data['Dependents'].fillna(loan_train_data['Dependents'].mode()[0])
loan_train_data['Dependents'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Dependents
# Non-Null Count  Dtype
# --------------  -----
# 599 non-null    category
# dtypes: category(1)
# memory usage: 950.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Dependents
# Non-Null Count  Dtype
# --------------  -----
# 599 non-null    category
# dtypes: category(1)
# memory usage: 950.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Dependents
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 950.0 bytes

# %%
loan_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    category
#  2   Married            614 non-null    category
#  3   Dependents         614 non-null    category
#  4   Education          614 non-null    category
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: category(4), float64(4), int64(1), object(4)
# memory usage: 46.3+ KB

# %% [markdown]
# # investigating Education

# %%
loan_train_data['Education'].info()
loan_train_data['Education'].unique()
loan_train_data['Education']=loan_train_data['Education'].astype('category')
loan_train_data['Education'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Education
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    object
# dtypes: object(1)
# memory usage: 4.9+ KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Education
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes

# %% [markdown]
# # investigating Self_Employed

# %%
loan_train_data['Self_Employed'].info()
loan_train_data['Self_Employed'].unique()
loan_train_data['Self_Employed']=loan_train_data['Self_Employed'].astype('category')
loan_train_data['Self_Employed']=loan_train_data['Self_Employed'].fillna(loan_train_data['Self_Employed'].mode()[0])
loan_train_data['Self_Employed'].info()
loan_train_data['Self_Employed'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Self_Employed
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Self_Employed
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
loan_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    category
#  2   Married            614 non-null    category
#  3   Dependents         614 non-null    category
#  4   Education          614 non-null    category
#  5   Self_Employed      614 non-null    category
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: category(5), float64(4), int64(1), object(3)
# memory usage: 42.2+ KB

# %% [markdown]
# ## Investigating ApplicantIncome

# %%
loan_train_data['ApplicantIncome'].info()
loan_train_data['ApplicantIncome'].sample(5)
loan_train_data['ApplicantIncome'].unique()\
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: ApplicantIncome
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    int64
# dtypes: int64(1)
# memory usage: 4.9 KB
# 105    3052
# 413    2253
# 583    1880
# 49     4000
# 463    5191
# Name: ApplicantIncome, dtype: int64

# %% [markdown]
# ## investigating CoapplicantIncome

# %%
loan_train_data['CoapplicantIncome'].info()
loan_train_data['CoapplicantIncome'].unique()
loan_train_data['CoapplicantIncome'].sample(10)
loan_train_data['CoapplicantIncome']=loan_train_data['CoapplicantIncome'].astype('int')
loan_train_data['CoapplicantIncome'].info()
loan_train_data['CoapplicantIncome'].sample(10)
loan_train_data['CoapplicantIncome'].unique()
loan_train_data['CoapplicantIncome'].isna().sum()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: CoapplicantIncome
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    int32
# dtypes: int32(1)
# memory usage: 2.5 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: CoapplicantIncome
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    int32
# dtypes: int32(1)
# memory usage: 2.5 KB
# 0

# %% [markdown]
# ## Investigating loan amount

# %%
loan_train_data['LoanAmount'].info()
loan_train_data['LoanAmount'].isna().sum()
loan_train_data[loan_train_data['LoanAmount'].isna()]
loan_train_data['LoanAmount']=loan_train_data['LoanAmount'].fillna(loan_train_data['LoanAmount'].median())
loan_train_data['LoanAmount'].isna().sum()
loan_train_data['LoanAmount'].unique()
loan_train_data['LoanAmount'].info()
loan_train_data.sample(10)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: LoanAmount
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    float64
# dtypes: float64(1)
# memory usage: 4.9 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: LoanAmount
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    float64
# dtypes: float64(1)
# memory usage: 4.9 KB
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 491  LP002562    Male     Yes          1  Not Graduate            No
# 35   LP001106    Male     Yes          0      Graduate            No
# 530  LP002717    Male     Yes          0      Graduate            No
# 45   LP001137  Female      No          0      Graduate            No
# 518  LP002683    Male      No          0      Graduate            No
# 300  LP001964    Male     Yes          0  Not Graduate            No
# ...

# %% [markdown]
# ## investigating Loan_Amount_Term

# %%
loan_train_data['Loan_Amount_Term'].info()
loan_train_data['Loan_Amount_Term'].unique
loan_train_data.sample(10)
loan_train_data['Loan_Amount_Term']=loan_train_data['Loan_Amount_Term'].fillna(loan_train_data['Loan_Amount_Term'].median())
loan_train_data['Loan_Amount_Term'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Loan_Amount_Term
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    float64
# dtypes: float64(1)
# memory usage: 4.9 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Loan_Amount_Term
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    float64
# dtypes: float64(1)
# memory usage: 4.9 KB

# %%
loan_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    category
#  2   Married            614 non-null    category
#  3   Dependents         614 non-null    category
#  4   Education          614 non-null    category
#  5   Self_Employed      614 non-null    category
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    int32
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: category(5), float64(3), int32(1), int64(1), object(3)
# memory usage: 39.8+ KB

# %% [markdown]
# ## Investigating Credit_History

# %%
loan_train_data['Credit_History'].info()
loan_train_data['Credit_History'].sample(10)
loan_train_data['Credit_History']=loan_train_data['Credit_History'].astype('category')
loan_train_data['Credit_History'].info()
loan_train_data['Credit_History']=loan_train_data['Credit_History'].fillna(loan_train_data['Credit_History'].mode()[0])
loan_train_data['Credit_History'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Credit_History
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Credit_History
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Credit_History
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes

# %%
loan_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    category
#  2   Married            614 non-null    category
#  3   Dependents         614 non-null    category
#  4   Education          614 non-null    category
#  5   Self_Employed      614 non-null    category
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    int32
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    category
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: category(6), float64(2), int32(1), int64(1), object(3)
# memory usage: 35.7+ KB

# %% [markdown]
# ## Investigating Property_Area

# %%
loan_train_data['Property_Area'].info()
loan_train_data.sample(100)
loan_train_data['Property_Area'].unique()
loan_train_data['Property_Area']=loan_train_data['Property_Area'].astype('category')
loan_train_data['Property_Area'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Property_Area
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 878.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Property_Area
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 878.0 bytes

# %% [markdown]
# ## Investigating Loan_Status

# %%
loan_train_data['Loan_Status'].info()
loan_train_data['Loan_Status'].unique()
loan_train_data.sample(10)
loan_train_data['Loan_Status']=loan_train_data['Loan_Status'].astype('category')
loan_train_data['Loan_Status'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Loan_Status
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Loan_Status
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    category
# dtypes: category(1)
# memory usage: 870.0 bytes

# %%
loan_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    category
#  2   Married            614 non-null    category
#  3   Dependents         614 non-null    category
#  4   Education          614 non-null    category
#  5   Self_Employed      614 non-null    category
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    int32
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    category
#  11  Property_Area      614 non-null    category
#  12  Loan_Status        614 non-null    category
# dtypes: category(8), float64(2), int32(1), int64(1), object(1)
# memory usage: 27.6+ KB

# %%
loan_train_data.sample(100)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 157  LP001543    Male     Yes          1      Graduate            No
# 192  LP001657    Male     Yes          0  Not Graduate            No
# 34   LP001100    Male      No          3      Graduate            No
# 336  LP002110    Male     Yes          1      Graduate            No
# 326  LP002068    Male      No          0      Graduate            No
# 567  LP002837    Male     Yes          3      Graduate            No
# 306  LP001993  Female      No          0      Graduate            No
# 154  LP001535    Male      No          0      Graduate            No
# 170  LP001581    Male     Yes          0  Not Graduate            No
# 213  LP001715    Male     Yes          3  Not Graduate           Yes
# 485  LP002544    Male     Yes          1  Not Graduate            No
# 599  LP002948    Male     Yes          2      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# ...
